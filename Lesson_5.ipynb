# %% [markdown]
# Тема "Предел функции": №4(с), "Теоремы о пределах": d,e,f.

# %% [markdown]
# ### №4
# ![image.png](attachment:image.png)

# %% [markdown]
# ((x+3)/x)^(4x+1) = (1+(3/x))^x(4+1/x)= e^(4+1/x)

# %% [markdown]
# ### "Теоремы о пределах":
# ![image.png](attachment:image.png)

# %% [markdown]
# d.) (4x+3)/(4x-3) = (4x-3+6)/(4x-3) = (1 + (6/(4x-3)))^6x = ((1 + (6/(4x-3)))^x)^6 = e^6<br>
# e.) (sin(x)+ln(x))/x  = sin(x) / x + ln(x)/ x = 1+(ln(x))/x<br>
# lim (1+((ln(x))/x))
